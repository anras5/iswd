# %% [markdown]
# # Projekt 2 - ELECTRE III i PROMETHEE
#
# #### Filip Marciniak 148148, Szymon Pasternak 148146

# %% [markdown]
# # Opis zbioru danych

# %% [markdown]
# 1. Jaka jest domena problemu?
#
# W problemie rozważamy koszykarzy z ligi NBA grających w sezonie 2023/2024.
#
# 2. Jakie jest źródło danych?
#
# Dane pochodzą z oficjalnej strony NBA - https://www.nba.com/stats/players/traditional.
#
# 3. Jaki jest punkt widzenia decydenta?
#
# Jako decydent zależy nam na znalezieniu rankingu wszystkich rozważanych koszykarzy.
#
# 4. Jaka jest liczba rozważanych wariantów? Czy w oryginalnym zbiorze danych było ich więcej?
#
# W przygotowanym zbiorze danych jest 38 wariantów. Ze strony NBA stats wybranych zostało 40 korzykarzy, którzy mają najwięcej punktów na mecz, a następnie usunięto takich, którzy mają poniżej 30 rozegranych meczów, ponieważ mogliby zaburzać dane. W oryginalnym zbiorze dostępnych jest 549 koszykarzy.

# %%
import pandas as pd

# %% [markdown]
# Poniżej przedstawiony został pełen zbiór danych.

# %%
df = pd.read_csv('./Basketball_players.csv', sep=';')
df
# Out:
#                      PLAYER   PTS   FG%   3P%   FT%   REB   AST  TOV   PF  +/-
# 0               Joel Embiid  35.3  53.3  36.6  88.3  11.3   5.7  3.7  2.9  6.9
# 1               Luka Doncic  33.9  48.7  37.4  78.7   9.1   9.8  4.0  2.1  3.5
# 2     Giannis Antetokounmpo  30.7  61.6  28.8  65.7  11.5   6.4  3.4  2.9  4.6
# 3   Shai Gilgeous-Alexander  30.4  54.0  36.7  87.1   5.6   6.3  2.2  2.5  7.9
# 4              Kevin Durant  27.6  52.9  42.2  85.5   6.8   5.2  3.3  1.7  3.8
# 5          Donovan Mitchell  27.4  46.8  37.3  86.2   5.3   6.1  2.9  2.2  7.0
# 6             Jalen Brunson  27.4  47.7  40.1  84.5   3.6   6.5  2.4  1.9  6.1
# 7              Jayson Tatum  27.3  47.2  37.8  83.2   8.2   4.9  2.5  2.0  8.8
# 8              Devin Booker  27.2  49.2  36.4  88.1   4.8   6.9  2.5  3.0  4.6
# 9             Stephen Curry  26.5  44.7  40.3  92.3   4.4   5.0  2.8  1.6  2.0
# 10             De'Aaron Fox  26.5  46.6  36.3  73.0   4.5   5.6  2.7  2.6  2.6
# 11               Trae Young  26.4  42.6  37.1  85.6   2.7  10.8  4.3  2.1 -2.2
# 12          Anthony Edwards  26.2  46.4  37.3  82.7   5.5   5.2  3.1  1.8  6.5
# 13             Nikola Jokic  26.1  58.1  35.0  82.8  12.2   9.0  2.9  2.5  8.2
# 14             Tyrese Maxey  25.8  44.9  37.9  86.7   3.7   6.1  1.7  2.2  3.5
# 15             LeBron James  25.3  53.0  40.5  74.8   7.3   8.1  3.3  1.2  2.7
# 16             Kyrie Irving  25.3  49.1  40.7  90.5   5.0   5.3  1.7  1.9  3.7
# 17            Anthony Davis  24.7  55.3  28.9  81.5  12.6   3.6  2.0  2.4  1.1
# 18           Damian Lillard  24.4  42.6  35.8  92.3   4.4   7.1  2.5  1.8  5.8
# 19            Julius Randle  24.0  47.2  31.1  78.1   9.2   5.0  3.5  2.7  4.7
# 20             Desmond Bane  23.7  46.4  38.1  87.0   4.4   5.5  2.7  2.9 -4.8
# 21            Kawhi Leonard  23.7  52.4  41.5  88.7   6.1   3.6  1.7  1.4  5.8
# 22            DeMar DeRozan  23.3  47.4  33.0  85.9   4.3   5.3  1.5  2.1 -1.0
# 23             Jaylen Brown  23.3  50.4  35.4  69.9   5.5   3.6  2.3  2.6  6.7
# 24          Lauri Markkanen  23.2  48.0  39.9  89.9   8.2   2.0  1.4  1.8  0.4
# 25          Zion Williamson  22.8  58.6  35.7  70.2   5.8   5.0  2.7  2.3  2.3
# 26          Dejounte Murray  22.7  46.4  36.6  80.4   5.3   6.2  2.4  1.7 -1.4
# 27          Anfernee Simons  22.6  43.0  38.5  91.6   3.6   5.5  2.7  2.1 -7.2
# 28              Paul George  22.5  47.0  40.9  89.7   5.3   3.6  2.0  2.8  6.3
# 29           Paolo Banchero  22.5  46.4  35.9  71.0   6.8   5.4  3.1  2.0 -0.2
# 30               Kyle Kuzma  22.4  46.7  33.9  77.9   6.5   4.3  2.7  2.2 -7.8
# 31        Jaren Jackson Jr.  22.3  44.2  32.0  80.5   5.6   2.3  2.4  3.6 -5.0
# 32          Cade Cunningham  22.3  44.8  35.0  86.6   4.3   7.5  3.4  2.5 -6.2
# 33       Karl-Anthony Towns  22.1  50.6  42.3  87.4   8.4   3.0  2.8  3.3  5.7
# 34            Pascal Siakam  21.8  53.5  34.1  73.0   7.0   4.5  1.8  2.4  0.9
# 35               Cam Thomas  21.8  44.4  35.7  84.9   3.2   2.9  1.9  2.1 -3.0
# 36             Jimmy Butler  21.4  50.1  41.5  85.6   5.4   4.8  1.7  1.2  3.1
# 37           Alperen Sengun  21.1  53.7  29.7  69.3   9.3   5.0  2.6  3.3  0.8

# %% [markdown]
# 5. Opisz jeden z rozważanych wariantów - jak jest oceniony na poszczególnych kryteriach, jak dobry jest na tle innych.
#
# **Nikola Jokic**:
# - PTS - uzyskuje dość dobry wynik, znajduje się na 14 miejscu na tym kryterium,
# - FG% - na tym kryterium jest jednym z najlepszych wariantów,
# - 3P% - na tym kryterium znajduje się mniej więcej w połowie,
# - FT% - podobnie jak kryterium 3P%
# - REB - wyróżnia się spośród innych wariantów dwucyfrowym wynikiem na tym kryterium, są jedynie 4 oceny dwucyfrowe,
# - AST - na tym kryterium również jest jednym z lepszych wariantów
# - TOV - na tym kryterium, radzi sobie gorzej niż inne warianty, ale o niewielką wartość
# - PF - na tym kryterium radzi sobie średnio
# - +/- - ostatnie kryterium zdecydowanie wyróżnia go spośród innych wariantów, uzyskuje na nim jedną z najlepszych ocen.
#
# 6. Ile rozważasz kryteriów? Czy było ich więcej w oryginalnym zbiorze danych?
#
# W problemie rozważanych jest 9 kryteriów. W oryginalnym zbiorze danych było ich więcej natomiast wybrane zostały takie, które uśredniają niektóre z dostępnych oryginalnie oraz najważniejsze, takie jak np. liczba punktów na mecz.
#
# 7. Jakie są typy poszczególnych kryteriów? Scharakteryzuj je pod kątem:
#
# Na wszystkich z kryteriów uzyskane wartości są ciągłe, ponieważ są to statystyki średnio na mecz.
# - PTS - ZYSK - średnia liczba punktów na mecz
# - FG% - ZYSK - procent trafionych rzutów
# - 3P% - ZYSK - procent trafionych rzutów 3 punktowych
# - FT% - ZYSK - procent trafionych rzutów osobistych
# - REB - ZYSK - średnia liczba zbiórek na mecz
# - AST - ZYSK - średnia liczba asyst na mecz
# - TOV - KOSZT - średnia liczba strat na mecz
# - PF - KOSZT - średnia liczba fauli na mecz
# - +/- - ZYSK - średnia różnica pomiędzy punktami zdobytymi i straconymi przez drużynę w czasie kiedy gracz był obecny na boisku na mecz
#
# Osiągane wartości:

# %%
df.describe()
# Out:
#              PTS        FG%        3P%        FT%        REB        AST  \
# count  38.000000  38.000000  38.000000  38.000000  38.000000  38.000000
# mean   25.102632  49.102632  36.681579  82.555263   6.386842   5.489474
# std     3.310629   4.594973   3.544761   7.195107   2.554505   1.891059
# min    21.100000  42.600000  28.800000  65.700000   2.700000   2.000000
# 25%    22.525000  46.400000  35.100000  78.250000   4.425000   4.575000
# 50%    24.200000  47.550000  36.650000  85.200000   5.550000   5.300000
# 75%    26.500000  52.775000  39.550000  87.325000   7.975000   6.275000
# max    35.300000  61.600000  42.300000  92.300000  12.600000  10.800000
#
#              TOV         PF        +/-
# count  38.000000  38.000000  38.000000
# mean    2.610526   2.271053   2.294737
# std     0.698953   0.566596   4.460696
# min     1.400000   1.200000  -7.800000
# 25%     2.050000   1.900000  -0.050000
# 50%     2.650000   2.200000   3.300000
# 75%     3.050000   2.600000   5.800000
# max     4.300000   3.600000   8.800000

# %% [markdown]
# 8. Jakie są wagi poszczególnych kryteriów?
#
# TODO
#
# 9. Czy istnieją jakieś dominacje w zbiorze wariantów? Jeśli tak, podaj je.
#
# TODO
#
# 10. Jak teoretycznie powinien prezentować się najlepszy wariant w Twoim zbiorze danych?
#
# TODO
#
# 11. Spośród rozważanych wariantów, który wydaje się być najlepszy/lepszy od innych i dlaczego?
#
# TODO
#
# 12. Spośród rozważanych wariantów, który wydaje się być najsłabszy/ znacząco słabszy od innych i dlaczego?
#
# TODO
